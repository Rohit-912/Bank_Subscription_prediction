# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('../Data/raw/train.csv')

# %%
df.head()
# Out:
#    id  age          job  marital  education default  balance housing loan  \
# 0   0   42   technician  married  secondary      no        7      no   no
# 1   1   38  blue-collar  married  secondary      no      514      no   no
# 2   2   36  blue-collar  married  secondary      no      602     yes   no
# 3   3   27      student   single  secondary      no       34     yes   no
# 4   4   26   technician  married  secondary      no      889     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome  y
# 0  cellular   25   aug       117         3     -1         0  unknown  0
# 1   unknown   18   jun       185         1     -1         0  unknown  0
# 2   unknown   14   may       111         2     -1         0  unknown  0
# 3   unknown   28   may        10         2     -1         0  unknown  0
# 4  cellular    3   feb       902         1     -1         0  unknown  1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 750000 entries, 0 to 749999
# Data columns (total 18 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         750000 non-null  int64
#  1   age        750000 non-null  int64
#  2   job        750000 non-null  object
#  3   marital    750000 non-null  object
#  4   education  750000 non-null  object
#  5   default    750000 non-null  object
#  6   balance    750000 non-null  int64
#  7   housing    750000 non-null  object
#  8   loan       750000 non-null  object
#  9   contact    750000 non-null  object
#  10  day        750000 non-null  int64
#  11  month      750000 non-null  object
#  12  duration   750000 non-null  int64
#  13  campaign   750000 non-null  int64
#  14  pdays      750000 non-null  int64
#  15  previous   750000 non-null  int64
#  16  poutcome   750000 non-null  object
#  17  y          750000 non-null  int64
# dtypes: int64(9), object(9)
# ...

# %%
df.isnull().sum()
# Out:
# id           0
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
df['poutcome'].unique()
# Out:
# array(['unknown', 'other', 'failure', 'success'], dtype=object)

# %%
sns.countplot(x='poutcome',data=df)
# Out:
# <Axes: xlabel='poutcome', ylabel='count'>

# %%
sns.countplot(x='poutcome',hue='y',data=df)
# Out:
# <Axes: xlabel='poutcome', ylabel='count'>

# %%
sns.countplot(x='y',data=df)
# Out:
# <Axes: xlabel='y', ylabel='count'>

# %%
df.shape
# Out:
# (750000, 18)

# %%
plt.figure(figsize=(16,10))
sns.countplot(x='job',hue='y',data=df)
# Out:
# <Axes: xlabel='job', ylabel='count'>

# %%
df['default'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
sns.countplot(x='housing',hue='y',data=df)
# Out:
# <Axes: xlabel='housing', ylabel='count'>

# %%
sns.histplot(data=df,x='age',hue='y',bins=40,kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.boxplot(x='y',y='age',data=df)
# Out:
# <Axes: xlabel='y', ylabel='age'>

# %%
numeric_df = df.select_dtypes(include=['number'])
corr_matrix = numeric_df.corr()
plt.figure(figsize=(12,10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
sns.countplot(x='month',hue='y',data=df)
# Out:
# <Axes: xlabel='month', ylabel='count'>

# %%
df.head()
# Out:
#    id  age          job  marital  education default  balance housing loan  \
# 0   0   42   technician  married  secondary      no        7      no   no
# 1   1   38  blue-collar  married  secondary      no      514      no   no
# 2   2   36  blue-collar  married  secondary      no      602     yes   no
# 3   3   27      student   single  secondary      no       34     yes   no
# 4   4   26   technician  married  secondary      no      889     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome  y
# 0  cellular   25   aug       117         3     -1         0  unknown  0
# 1   unknown   18   jun       185         1     -1         0  unknown  0
# 2   unknown   14   may       111         2     -1         0  unknown  0
# 3   unknown   28   may        10         2     -1         0  unknown  0
# 4  cellular    3   feb       902         1     -1         0  unknown  1

# %%
sns.countplot(x='marital',hue='y',data=df)
# Out:
# <Axes: xlabel='marital', ylabel='count'>

# %%
df['campaign'].unique()
# Out:
# array([ 3,  1,  2, 25,  5,  7,  4, 11,  6,  9,  8, 16, 10, 15, 12, 13, 19,
#        17, 14, 22, 23, 34, 18, 29, 24, 30, 21, 27, 36, 28, 20, 35, 32, 26,
#        40, 37, 31, 33, 63, 51, 46, 39, 43, 48, 41, 44, 38, 42, 55, 50, 58,
#        45])

# %%
df['education'].unique()
# Out:
# array(['secondary', 'primary', 'tertiary', 'unknown'], dtype=object)

# %%
encode={'unknown':0,'primary':1,'secondary':2,'tertiary':3}
df['education']=df['education'].map(encode)

# %%
df.head()
# Out:
#    id  age          job  marital  education default  balance housing loan  \
# 0   0   42   technician  married          2      no        7      no   no
# 1   1   38  blue-collar  married          2      no      514      no   no
# 2   2   36  blue-collar  married          2      no      602     yes   no
# 3   3   27      student   single          2      no       34     yes   no
# 4   4   26   technician  married          2      no      889     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome  y
# 0  cellular   25   aug       117         3     -1         0  unknown  0
# 1   unknown   18   jun       185         1     -1         0  unknown  0
# 2   unknown   14   may       111         2     -1         0  unknown  0
# 3   unknown   28   may        10         2     -1         0  unknown  0
# 4  cellular    3   feb       902         1     -1         0  unknown  1

# %%
df['housing'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
df['loan'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
df['default'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
sns.countplot(x='default',hue='y',data=df)
# Out:
# <Axes: xlabel='default', ylabel='count'>

# %%
df['poutcome'].unique()
# Out:
# array(['unknown', 'other', 'failure', 'success'], dtype=object)

# %%
sns.histplot(data=df,x='balance',hue='y',bins=40)
# Out:
# <Axes: xlabel='balance', ylabel='Count'>

# %%
sns.boxplot(x='y',y='balance',data=df)
# Out:
# <Axes: xlabel='y', ylabel='balance'>

# %%
df['balance_shifted'] = df['balance'] - df['balance'].min() + 1 

df['log_balance'] = np.log(df['balance_shifted'])

# %%
sns.histplot(data=df,x='log_balance',hue='y',bins=40)
# Out:
# <Axes: xlabel='log_balance', ylabel='Count'>

# %%
df.head()
# Out:
#    id  age          job  marital  education default  balance housing loan  \
# 0   0   42   technician  married          2      no        7      no   no
# 1   1   38  blue-collar  married          2      no      514      no   no
# 2   2   36  blue-collar  married          2      no      602     yes   no
# 3   3   27      student   single          2      no       34     yes   no
# 4   4   26   technician  married          2      no      889     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome  y  \
# 0  cellular   25   aug       117         3     -1         0  unknown  0
# 1   unknown   18   jun       185         1     -1         0  unknown  0
# 2   unknown   14   may       111         2     -1         0  unknown  0
# 3   unknown   28   may        10         2     -1         0  unknown  0
# 4  cellular    3   feb       902         1     -1         0  unknown  1
#
#    log_balance  balance_shifted
# 0     8.990566             8027
# ...

# %%
df_test=pd.read_csv('../Data/raw/test.csv')

# %%
df_test.head()
# Out:
#        id  age            job  marital  education default  balance housing  \
# 0  750000   32    blue-collar  married  secondary      no     1397     yes
# 1  750001   44     management  married   tertiary      no       23     yes
# 2  750002   36  self-employed  married    primary      no       46     yes
# 3  750003   58    blue-collar  married  secondary      no    -1380     yes
# 4  750004   28     technician   single  secondary      no     1950     yes
#
#   loan   contact  day month  duration  campaign  pdays  previous poutcome
# 0   no   unknown   21   may       224         1     -1         0  unknown
# 1   no  cellular    3   apr       586         2     -1         0  unknown
# 2  yes  cellular   13   may       111         2     -1         0  unknown
# 3  yes   unknown   29   may       125         1     -1         0  unknown
# 4   no  cellular   22   jul       181         1     -1         0  unknown
